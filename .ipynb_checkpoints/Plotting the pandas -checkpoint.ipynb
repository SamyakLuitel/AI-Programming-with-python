# %% [markdown]
# # pandas visualization

# %%
# %matplotlib notebook
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['seaborn-dark-palette',
#  'seaborn-paper',
#  'grayscale',
#  '_classic_test',
#  'seaborn-whitegrid',
#  'seaborn-notebook',
#  'seaborn-bright',
#  'fivethirtyeight',
#  'dark_background',
#  'seaborn-dark',
#  'seaborn-white',
#  'seaborn-muted',
#  'tableau-colorblind10',
#  'seaborn-poster',
#  'seaborn',
#  'seaborn-pastel',
#  'classic',
#  '_classic_test_patch',
#  'bmh',
#  'ggplot',
#  'fast',
#  'seaborn-ticks',
#  'seaborn-deep',
#  'Solarize_Light2',
#  'seaborn-darkgrid',
#  'seaborn-talk',
#  'seaborn-colorblind']

# %%
plt.style.use('seaborn-colorblind')

# %% [markdown]
# # DataFrame.plot

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0),
                 'B': np.random.randn(365).cumsum(0)+20,
                 'C':np.random.randn(365).cumsum(0)-20}, 
                 index = pd.date_range('13/4/2020', periods = 365))

# %%
df.head()
# Out:
#                    A          B          C
# 2020-04-13 -1.085631  20.059291 -20.230904
# 2020-04-14 -0.088285  21.803332 -16.659325
# 2020-04-15  0.194693  20.835588 -17.055481
# 2020-04-16 -1.311601  21.255156 -17.093802
# 2020-04-17 -1.890202  21.462083 -19.518638

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
df.plot('A','B', kind = 'scatter')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
df.plot.scatter('A','C', c='B', s = df['B'],colormap ='viridis')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
ax= df.plot.scatter('A','C', c='B', s = df['B'],colormap ='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
df.plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
#kernel density estimate plots

df.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# # pandas.plotting

# %%
iris = pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
pd.plotting.scatter_matrix(iris)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c97641750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95e0ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c960fee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c96120150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c96126450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c9614d750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c96151a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95a95d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95c720d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95c9c3d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95c39690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c960a2d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c96087550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95a3bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95d25590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c962bfd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95be25d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95e54dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c960d8610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95ad7e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95d7a650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95f1ce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95ebd690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c961f8e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0c95b186d0>]],
#       dtype=object)

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris,"Species")
# Out:
# <img src="data:image/png;base64,..." width="639.85">
